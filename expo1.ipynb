# %% [markdown]
# <a href="https://colab.research.google.com/github/Manjula-kuruva/TODO-List-app/blob/main/expo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/emojify
# Out:
# /content/drive/MyDrive/emojify

# %%
# !pip install keras tensorflow opencv-python-headless pillow

# %%
color_mode="grayscale"  # ✅ use this, NOT "gray_framescale"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_dir = '/content/drive/MyDrive/Emoji_Creator/data/train'
val_dir = '/content/drive/MyDrive/Emoji_Creator/data/test'

# %%
import os

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# List contents to find your correct folder
# !ls '/content/drive/MyDrive'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '12. USER INTERFACE DESIGN.pptx'
# '1 Java introduction, classes and objects.ppt'
# '1. SOFTWARE TESTING STRATEGIES (1).pptx'
# '1. SOFTWARE TESTING STRATEGIES.pptx'
#  20.pdf
# '2 (1).gdoc'
#  2c.gdoc
#  2.gdoc
# '3 (1).gdoc'
#  3.gdoc
#  4.gdoc
# 'a (1).gdoc'
# 'a (2).gdoc'
# 'a (3).gdoc'
# 'a (4).gdoc'
#  a.gdoc
#  Classroom
# 'Colab Notebooks'
# 'DS Imp Ques (1).gdoc'
# 'DS Imp Ques (2).gdoc'
# 'DS Imp Ques (3).gdoc'
# 'DS Imp Ques (4).gdoc'
# 'DS Imp Ques (5).gdoc'
# 'DS Imp Ques.gdoc'
# 'DS Mid-II imp ques (10).gdoc'
# 'DS Mid-II imp ques (11).gdoc'
# 'DS Mid-II imp ques (12).gdoc'
# 'DS Mid-II imp ques (13).gdoc'
# 'DS Mid-II imp ques (14).gdoc'
# 'DS Mid-II imp ques (1).gdoc'
# 'DS Mid-II imp ques (2).gdoc'
# 'DS Mid-II imp ques (3).gdoc'
# 'DS Mid-II imp ques (4).gdoc'
# 'DS Mid-II imp ques (5).gdoc'
# 'DS Mid-II imp ques (6).gdoc'
# ...

# %%
# !ls '/content/drive/MyDrive/emojify'
# Out:
# train

# %%
# !ls '/content/drive/MyDrive/emojify'
# !ls '/content/drive/MyDrive/emojify/test'
# Out:
# train
# ls: cannot access '/content/drive/MyDrive/emojify/test': No such file or directory

# %%
train_dir = '/content/drive/MyDrive/emojify/train'
val_dir = '/content/drive/MyDrive/emojify/test'

# %%
# !ls '/content/drive/MyDrive'
# Out:
# '12. USER INTERFACE DESIGN.pptx'
# '1 Java introduction, classes and objects.ppt'
# '1. SOFTWARE TESTING STRATEGIES (1).pptx'
# '1. SOFTWARE TESTING STRATEGIES.pptx'
#  20.pdf
# '2 (1).gdoc'
#  2c.gdoc
#  2.gdoc
# '3 (1).gdoc'
#  3.gdoc
#  4.gdoc
# 'a (1).gdoc'
# 'a (2).gdoc'
# 'a (3).gdoc'
# 'a (4).gdoc'
#  a.gdoc
#  Classroom
# 'Colab Notebooks'
# 'DS Imp Ques (1).gdoc'
# 'DS Imp Ques (2).gdoc'
# 'DS Imp Ques (3).gdoc'
# 'DS Imp Ques (4).gdoc'
# 'DS Imp Ques (5).gdoc'
# 'DS Imp Ques.gdoc'
# 'DS Mid-II imp ques (10).gdoc'
# 'DS Mid-II imp ques (11).gdoc'
# 'DS Mid-II imp ques (12).gdoc'
# 'DS Mid-II imp ques (13).gdoc'
# 'DS Mid-II imp ques (14).gdoc'
# 'DS Mid-II imp ques (1).gdoc'
# 'DS Mid-II imp ques (2).gdoc'
# 'DS Mid-II imp ques (3).gdoc'
# 'DS Mid-II imp ques (4).gdoc'
# 'DS Mid-II imp ques (5).gdoc'
# 'DS Mid-II imp ques (6).gdoc'
# 'DS Mid-II imp ques (7).gdoc'
# 'DS Mid-II imp ques (8).gdoc'
# 'DS Mid-II imp ques (9).gdoc'
# 'DS Mid-II imp ques.gdoc'
# 'ds programs.gdoc'
# ...

# %%
# !ls '/content/drive/MyDrive/emojify'
# Out:
# train

# %%
train_dir = '/content/drive/MyDrive/emojify/train'
val_dir = '/content/drive/MyDrive/emojify/train'  # Temporarily reuse train data

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode="grayscale",
    class_mode='categorical'
)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode="grayscale",
    class_mode='categorical'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-907252449.py in <cell line: 0>()
#       3
#       4 train_generator = train_datagen.flow_from_directory(
# ----> 5     train_dir,
#       6     target_size=(48, 48),
#       7     batch_size=64,
#
# NameError: name 'train_dir' is not defined

# %%
# !ls -R '/content/drive/MyDrive/emojify'
# Out:
# /content/drive/MyDrive/emojify:
# train
#
# /content/drive/MyDrive/emojify/train:
# emoji-creator-project-code
#
# /content/drive/MyDrive/emojify/train/emoji-creator-project-code:
# gui.py	train.py

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-52a78d35-ce6a-4515-b8af-c2ed4a429f72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52a78d35-ce6a-4515-b8af-c2ed4a429f72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile("FER2013.zip", 'r') as zip_ref:
    zip_ref.extractall("FER2013")  # Extracts to folder named 'FER2013'

# %%
# !ls FER2013
# !ls FER2013/train
# !ls FER2013/test
# Out:
# test  train
# angry  disgust	fear  happy  neutral  sad  surprise
# angry  disgust	fear  happy  neutral  sad  surprise

# %%
train_dir = 'FER2013/train'
val_dir = 'FER2013/test'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Rescale the image pixel values
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

# Load training data
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode='grayscale',
    class_mode='categorical'
)

# Load validation data
validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode='grayscale',
    class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

model = Sequential()

# 1st convolution layer
model.add(Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 2nd convolution layer
model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 3rd convolution layer
model.add(Conv2D(128, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Fully connected layer
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))  # 7 emotions

# %%
from tensorflow.keras.optimizers import Adam

model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
import tensorflow as tf
tf.config.run_functions_eagerly(True)

# %%
# Train for more epochs without EarlyStopping
model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=50  # You can change this to any number you want
)

# Evaluate on validation set
loss, acc = model.evaluate(validation_generator)
print("✅ Final Validation Accuracy:", acc)

# Save your model
model.save("emotion_model_epoch50.h5")
print("✅ Model saved as emotion_model_epoch50.h5")
# Out:
# Epoch 1/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 106s 232ms/step - accuracy: 0.2312 - loss: 1.8620 - val_accuracy: 0.2471 - val_loss: 1.8738
# Epoch 2/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 104s 231ms/step - accuracy: 0.2375 - loss: 1.8325 - val_accuracy: 0.2470 - val_loss: 1.8523
# Epoch 3/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 104s 232ms/step - accuracy: 0.2518 - loss: 1.8047 - val_accuracy: 0.2920 - val_loss: 1.8000
# Epoch 4/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 108s 240ms/step - accuracy: 0.2825 - loss: 1.7536 - val_accuracy: 0.3495 - val_loss: 1.7086
# Epoch 5/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 106s 235ms/step - accuracy: 0.3312 - loss: 1.7015 - val_accuracy: 0.3752 - val_loss: 1.6598
# Epoch 6/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 106s 236ms/step - accuracy: 0.3517 - loss: 1.6540 - val_accuracy: 0.3906 - val_loss: 1.6239
# Epoch 7/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 106s 235ms/step - accuracy: 0.3698 - loss: 1.6238 - val_accuracy: 0.4036 - val_loss: 1.5736
# Epoch 8/50
# ...

# %%
loss, acc = model.evaluate(validation_generator)
print("Validation accuracy:", acc)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 15s 136ms/step - accuracy: 0.5656 - loss: 1.1465
# Validation accuracy: 0.5638060569763184

# %%
model.save('emotion_model.epoch50.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save('/content/drive/MyDrive/FER2013/emotion_model.epoch50.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.models import load_model
model = load_model('emotion_model.epoch50.h5')  # or provide full path if needed
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-10b4813a-55c5-47c1-b5eb-921c1ab94fa2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10b4813a-55c5-47c1-b5eb-921c1ab94fa2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from keras.models import load_model
model = load_model('emotion_model.epoch50.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import cv2
import numpy as np

# Load and preprocess image
img = cv2.imread('photo.jfif', cv2.IMREAD_GRAYSCALE)
img = cv2.resize(img, (48, 48))
img = img.reshape(1, 48, 48, 1) / 255.0

# Predict emotion
prediction = model.predict(img)
print("Predicted class:", np.argmax(prediction))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# Predicted class: 5

# %%
model_path = '/content/drive/MyDrive/FER2013/emotion_model.h5'
model = load_model(model_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import cv2
import numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt
from PIL import Image
import IPython.display as display

# Load the model
model = load_model('emotion_model.h5')

# Emotion labels and corresponding emojis (Unicode)
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
emotion_emojis = {
    'Angry': '😠',
    'Disgust': '🤢',
    'Fear': '😨',
    'Happy': '😄',
    'Sad': '😢',
    'Surprise': '😲',
    'Neutral': '😐'
}

# Upload image
from google.colab import files
uploaded = files.upload()
img_path = list(uploaded.keys())[0]

# Read and preprocess image
img = cv2.imread(img_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
face = cv2.resize(gray, (48, 48))
face = face / 255.0
face = face.reshape(1, 48, 48, 1)

# Predict emotion
prediction = model.predict(face)
predicted_label = emotion_labels[np.argmax(prediction)]
predicted_emoji = emotion_emojis[predicted_label]

# Display result
plt.figure(figsize=(6,3))

# Show uploaded image
plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title(f'Emotion: {predicted_label}')
plt.axis('off')

# Show emoji
plt.subplot(1,2,2)
plt.text(0.5, 0.5, predicted_emoji, fontsize=80, ha='center', va='center')
plt.axis('off')
plt.title('Emoji')

plt.tight_layout()
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#      <input type="file" id="files-01ebe1f0-2c78-47e3-80ae-12567fe17779" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-01ebe1f0-2c78-47e3-80ae-12567fe17779">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
import os
print(sorted(os.listdir('FER2013/train')))
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
# Step 2: Import required modules
import cv2
import numpy as np
from keras.models import load_model
from google.colab.patches import cv2_imshow
from google.colab import files

# Step 3: Load the trained model
model = load_model('emotion_model.h5')  # Make sure you uploaded it

# Step 4: Define emotion class to emoji mapping
emotion_dict = {
    0: "😠 Angry",
    1: "🤢 Disgust",
    2: "😨 Fear",
    3: "😄 Happy",
    4: "😐 Neutral",
    5: "😢 Sad",
    6: "😲 Surprise"
}

# Step 5: Upload an image
uploaded = files.upload()

# Step 6: Read, preprocess, and predict
for filename in uploaded.keys():
    # Read image in grayscale
    img = cv2.imread(filename, cv2.IMREAD_GRAYSCALE)

    # Resize to 48x48
    img = cv2.resize(img, (48, 48))

    # Normalize and reshape for model
    img_input = img.reshape(1, 48, 48, 1) / 255.0

    # Predict emotion
    prediction = model.predict(img_input)
    predicted_class = int(np.argmax(prediction))
    predicted_emoji = emotion_dict[predicted_class]

    # Show image and result
    print(f"Predicted Emotion: {predicted_emoji}")
    cv2_imshow(cv2.resize(img, (150, 150)))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#      <input type="file" id="files-d54d0a94-9d9e-455b-bb05-1cbe8f9323df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d54d0a94-9d9e-455b-bb05-1cbe8f9323df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
loss, acc = model.evaluate(x_test, y_test)
print("Test accuracy:", acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-9df3be5d1fc3> in <cell line: 0>()
# ----> 1 loss, acc = model.evaluate(x_test, y_test)
#       2 print("Test accuracy:", acc)
#
# NameError: name 'x_test' is not defined
